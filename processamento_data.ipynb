# %%
from feature_engineering import EngenhariaFeaturesTelco
import pandas as pd 
pd.set_option('display.max_columns', None)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from feature_engineering import EngenhariaFeaturesTelco
#       2 import pandas as pd
#       3 pd.set_option('display.max_columns', None)
#
# ImportError: cannot import name 'EngenhariaFeaturesTelco' from 'feature_engineering' (c:\Users\gui08\OneDrive\Documentos\Tech_challenge_1\feature_engineering.py)

# %%
engenharia_features = EngenhariaFeaturesTelco()
df = pd.read_excel('data\\Telco_customer_churn.xlsx')
df_engineered = engenharia_features.preparar_features(df)

# %%
df_engineered.head()
# Out:
#           City  Gender Senior Citizen Partner Dependents  Tenure Months  \
# 0  Los Angeles    Male             No      No         No              2
# 1  Los Angeles  Female             No      No        Yes              2
# 2  Los Angeles  Female             No      No        Yes              8
# 3  Los Angeles  Female             No     Yes        Yes             28
# 4  Los Angeles    Male             No      No        Yes             49
#
#   Phone Service Multiple Lines Internet Service Online Security Online Backup  \
# 0           Yes             No              DSL             Yes           Yes
# 1           Yes             No      Fiber optic              No            No
# 2           Yes            Yes      Fiber optic              No            No
# 3           Yes            Yes      Fiber optic              No            No
# 4           Yes            Yes      Fiber optic              No           Yes
#
# ...
